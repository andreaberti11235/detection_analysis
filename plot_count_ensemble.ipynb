# %% [markdown]
# # Resulting Plots

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ## Variazione soglia IOU (detection)

# %% [markdown]
# Total number of masses = 240

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#    nr_TP  nr_FP  nr_FN
# 0  175.0  476.0   65.0
# 1  168.0  483.0   72.0
# 2  155.0  496.0   85.0
# 3  139.0  512.0  101.0
# 4  135.0  516.0  105.0

# %%
iou_th = np.array([0.1, 0.15, 0.2, 0.25, 0.3])

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('IOU threshold')
ax1.set_ylabel('Counts')
ax1.plot(iou_th, df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(iou_th, df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(iou_th, df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Variazione soglia Conf

# %% [markdown]
# Total number of masses = 240

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_conf.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#    nr_TP  nr_FP  nr_FN
# 0  175.0  476.0   65.0
# 1  158.0  360.0   82.0
# 2  151.0  295.0   89.0
# 3  131.0  234.0  109.0
# 4  112.0  188.0  128.0
# 5  106.0  158.0  134.0

# %%
iou_th = np.array([0.1, 0.15, 0.2, 0.25, 0.3, 0.35])

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(iou_th, df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(iou_th, df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(iou_th, df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Variazione soglia Conf senza aumentazione di slice (solo su slice annotate)

# %% [markdown]
# Total number of masses = 33

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_conf_originals.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#     nr_TP  nr_FP  nr_FN
# 0    29.0   72.0    4.0
# 1    25.0   58.0    8.0
# 2    23.0   47.0   10.0
# 3    21.0   37.0   12.0
# 4    18.0   29.0   15.0
# 5    18.0   24.0   15.0
# 6    17.0   20.0   16.0
# 7    16.0   17.0   17.0
# 8    16.0   13.0   17.0
# 9    16.0   10.0   17.0
# 10   16.0    9.0   17.0
# 11   15.0    7.0   18.0

# %%
iou_th = np.array([0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65])

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts TP and FN')
ax1.plot(iou_th, df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(iou_th, df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(iou_th, df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Provo a prendere solo le prime n detection per valore di conf

# %% [markdown]
# Total number of masses = 33

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_conf_originals_first2.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#    nr_TP  nr_FP  nr_FN
# 0   18.0   13.0   15.0
# 1   25.0   37.0    8.0
# 2   26.0   60.0    7.0

# %%
first_n = np.arange(1, 4)

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('top N')
ax1.set_ylabel('Counts')
ax1.plot(first_n, df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(first_n, df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(first_n, df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Provo a prendere solo le detection che hanno una conf entro un certo intervallo da quella della detection massima

# %% [markdown]
# Total number of masses = 33

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_only_originals_percentage_from_max.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#    nr_TP  nr_FP  nr_FN
# 0   13.0    5.0   20.0
# 1   15.0    8.0   18.0
# 2   15.0   11.0   18.0
# 3   16.0   31.0   17.0
# 4   17.0   35.0   16.0

# %%
interval_percentage = np.array([0.3, 0.4, 0.5, 0.8, 0.9])

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('top N')
ax1.set_ylabel('Counts')
ax1.plot(interval_percentage, df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(interval_percentage, df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(interval_percentage, df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Analisi sui singoli modelli

# %% [markdown]
# ### V5

# %% [markdown]
# #### IOU_th = 0.1

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v5/conf_th_variation_iou_1e-1.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#     conf_th  nr_TP  nr_FP  nr_FN
# 0      0.10   25.0   56.0    8.0
# 1      0.15   18.0   45.0   15.0
# 2      0.20   14.0   35.0   19.0
# 3      0.25   12.0   25.0   21.0
# 4      0.30   10.0   20.0   23.0
# 5      0.35   10.0   13.0   23.0
# 6      0.40    8.0    7.0   25.0
# 7      0.45    6.0    4.0   27.0
# 8      0.50    3.0    3.0   30.0
# 9      0.55    1.0    2.0   32.0
# 10     0.60    0.0    0.0   33.0
# 11     0.65    0.0    0.0   33.0

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ### V5

# %% [markdown]
# #### IOU_th = 0.2

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v5/conf_th_variation_iou_2e-1.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#     conf_th  nr_TP  nr_FP  nr_FN
# 0      0.10   22.0   59.0   11.0
# 1      0.15   18.0   45.0   15.0
# 2      0.20   14.0   35.0   19.0
# 3      0.25   12.0   25.0   21.0
# 4      0.30   10.0   20.0   23.0
# 5      0.35   10.0   13.0   23.0
# 6      0.40    8.0    7.0   25.0
# 7      0.45    6.0    4.0   27.0
# 8      0.50    3.0    3.0   30.0
# 9      0.55    1.0    2.0   32.0
# 10     0.60    0.0    0.0   33.0
# 11     0.65    0.0    0.0   33.0

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ### V8

# %% [markdown]
# #### IOU_th = 0.1

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v8/conf_th_variation_iou_1e-1.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#     conf_th  nr_TP  nr_FP  nr_FN
# 0      0.10   21.0   25.0   12.0
# 1      0.15   20.0   20.0   13.0
# 2      0.20   19.0   18.0   14.0
# 3      0.25   16.0   17.0   17.0
# 4      0.30   15.0   11.0   18.0
# 5      0.35   15.0   11.0   18.0
# 6      0.40   14.0   11.0   19.0
# 7      0.45   14.0   10.0   19.0
# 8      0.50   13.0    8.0   20.0
# 9      0.55   13.0    6.0   20.0
# 10     0.60   12.0    6.0   21.0
# 11     0.65   12.0    4.0   21.0

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ### V8

# %% [markdown]
# #### IOU_th = 0.2

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v8/conf_th_variation_iou_2e-1.txt'
df = pd.read_csv(txt_file, sep= ' ')

# %%
df
# Out:
#     conf_th  nr_TP  nr_FP  nr_FN
# 0      0.10   20.0   26.0   13.0
# 1      0.15   19.0   21.0   14.0
# 2      0.20   18.0   19.0   15.0
# 3      0.25   15.0   18.0   18.0
# 4      0.30   14.0   12.0   19.0
# 5      0.35   14.0   12.0   19.0
# 6      0.40   13.0   12.0   20.0
# 7      0.45   13.0   11.0   20.0
# 8      0.50   12.0    9.0   21.0
# 9      0.55   12.0    7.0   21.0
# 10     0.60   11.0    7.0   22.0
# 11     0.65   11.0    5.0   22.0

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df.loc[:, 'conf_th'], df.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Comparison

# %%
txt_v5_1 = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v5/conf_th_variation_iou_1e-1.txt'
df_v5_1 = pd.read_csv(txt_v5_1, sep= ' ')

txt_v5_2 = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v5/conf_th_variation_iou_2e-1.txt'
df_v5_2 = pd.read_csv(txt_v5_2, sep= ' ')

txt_v8_1 = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v8/conf_th_variation_iou_1e-1.txt'
df_v8_1 = pd.read_csv(txt_v8_1, sep= ' ')

txt_v8_2 = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/count_v8/conf_th_variation_iou_2e-1.txt'
df_v8_2 = pd.read_csv(txt_v8_2, sep= ' ')

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 15))
ax1, ax3, ax5, ax7 = ax[0, 0], ax[0, 1], ax[1, 0], ax[1, 1]
# First plot
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(df_v5_1.loc[:, 'conf_th'], df_v5_1.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df_v5_1.loc[:, 'conf_th'], df_v5_1.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df_v5_1.loc[:, 'conf_th'], df_v5_1.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax1.set_title('V5, IOU_th=0.1')

# Second plot
ax3.set_xlabel('Conf threshold')
ax3.set_ylabel('Counts')
ax3.plot(df_v5_2.loc[:, 'conf_th'], df_v5_2.loc[:, 'nr_TP'], '-o', label='True Positives')
ax3.plot(df_v5_2.loc[:, 'conf_th'], df_v5_2.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax4 = ax3.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax4.set_ylabel('Counts FP', color=color)
ax4.plot(df_v5_2.loc[:, 'conf_th'], df_v5_2.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax4.tick_params(axis='y', labelcolor=color)

ax3.legend(loc='upper left')
ax4.legend(loc='upper right')

ax3.set_title('V5, IOU_th=0.2')

# Third plot
ax5.set_xlabel('Conf threshold')
ax5.set_ylabel('Counts')
ax5.plot(df_v8_1.loc[:, 'conf_th'], df_v8_1.loc[:, 'nr_TP'], '-o', label='True Positives')
ax5.plot(df_v8_1.loc[:, 'conf_th'], df_v8_1.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax6 = ax5.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax6.set_ylabel('Counts FP', color=color)
ax6.plot(df_v8_1.loc[:, 'conf_th'], df_v8_1.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax6.tick_params(axis='y', labelcolor=color)

ax5.legend(loc='upper left')
ax6.legend(loc='upper right')

ax5.set_title('V8, IOU_th=0.1')

# Fourth plot
ax7.set_xlabel('Conf threshold')
ax7.set_ylabel('Counts')
ax7.plot(df_v8_2.loc[:, 'conf_th'], df_v8_2.loc[:, 'nr_TP'], '-o', label='True Positives')
ax7.plot(df_v8_2.loc[:, 'conf_th'], df_v8_2.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax8 = ax7.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax8.set_ylabel('Counts FP', color=color)
ax8.plot(df_v8_2.loc[:, 'conf_th'], df_v8_2.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax8.tick_params(axis='y', labelcolor=color)

ax7.legend(loc='upper left')
ax8.legend(loc='upper right')

ax7.set_title('V8, IOU_th=0.2')

# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.3)
