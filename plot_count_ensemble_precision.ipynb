# %% [markdown]
# # Resulting Plots

# %% [markdown]
# Analisi dei risultati ottenuti utilizzando la Precision come fattore di pesatura dei due modelli nell'ensemble.

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ## Variazione soglia IOU (detection)

# %% [markdown]
# Variazione soglia, avendo fissato IOU per detection a 0.1. Analisi con ensemble ottenuto tramite media degli score di conf.

# %% [markdown]
# Total number of masses = 33

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_originals_precision_iouth_1e-1.txt'
df_mean = pd.read_csv(txt_file, sep= ' ')

# %%
df_mean
# Out:
#     conf_th  nr_TP  nr_FP  nr_FN
# 0      0.05   25.0   60.0    8.0
# 1      0.10   20.0   30.0   13.0
# 2      0.15   18.0   15.0   15.0
# 3      0.20   16.0   13.0   17.0
# 4      0.25   14.0    9.0   19.0
# 5      0.30   14.0    8.0   19.0
# 6      0.35   13.0    5.0   20.0
# 7      0.40    9.0    2.0   24.0
# 8      0.45    8.0    2.0   25.0
# 9      0.50    5.0    0.0   28.0
# 10     0.55    4.0    0.0   29.0
# 11     0.60    0.0    0.0   33.0
# 12     0.65    1.0    0.0   32.0

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts TP and FN')
ax1.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# Variazione soglia, avendo fissato IOU per detection a 0.2. Analisi con ensemble ottenuto tramite media degli score di conf.

# %% [markdown]
# Total number of masses = 33

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_originals_precision_iouth_2e-1.txt'
df_mean = pd.read_csv(txt_file, sep= ' ')

# %%
df_mean
# Out:
#     conf_th  nr_TP  nr_FP  nr_FN
# 0      0.05   23.0   51.0   10.0
# 1      0.10   18.0   26.0   15.0
# 2      0.15   17.0   16.0   16.0
# 3      0.20   15.0   13.0   18.0
# 4      0.25   13.0   10.0   20.0
# 5      0.30   13.0    9.0   20.0
# 6      0.35   11.0    4.0   22.0
# 7      0.40    8.0    2.0   25.0
# 8      0.45    6.0    0.0   27.0
# 9      0.50    4.0    0.0   29.0
# 10     0.55    3.0    0.0   30.0
# 11     0.60    0.0    0.0   33.0
# 12     0.65    0.0    0.0   33.0

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts TP and FN')
ax1.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

fig.legend()
#fig.tight_layout()

# %% [markdown]
# ## Comparison with previous case

# %% [markdown]
# Confronto tra ensemble ottenuto facendo la media e ensemble ottenuto facendo la somma.

# %%
txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_originals_precision_iouth_1e-1.txt'
df_mean = pd.read_csv(txt_file, sep= ' ')

txt_file = '/Users/andreaberti/Documents/work/DBT/test_inference/plot_ensemble/detections_conf_originals.txt'
df_sum = pd.read_csv(txt_file, sep= ' ')

# %%
df_sum
# Out:
#     nr_TP  nr_FP  nr_FN
# 0    29.0   72.0    4.0
# 1    25.0   58.0    8.0
# 2    23.0   47.0   10.0
# 3    21.0   37.0   12.0
# 4    18.0   29.0   15.0
# 5    18.0   24.0   15.0
# 6    17.0   20.0   16.0
# 7    16.0   17.0   17.0
# 8    16.0   13.0   17.0
# 9    16.0   10.0   17.0
# 10   16.0    9.0   17.0
# 11   15.0    7.0   18.0

# %%
iou_th = np.array([0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65])

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))
ax1, ax3 = ax[0], ax[1]
# First plot
ax1.set_xlabel('Conf threshold')
ax1.set_ylabel('Counts')
ax1.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_TP'], '-o', label='True Positives')
ax1.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Counts FP', color=color)
ax2.plot(df_mean.loc[:, 'conf_th'], df_mean.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax2.tick_params(axis='y', labelcolor=color)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

ax1.set_title('Ensemble with Mean, IOU_th=0.1')


# Second plot
ax3.set_xlabel('Conf threshold')
ax3.set_ylabel('Counts')
ax3.plot(iou_th, df_sum.loc[:, 'nr_TP'], '-o', label='True Positives')
ax3.plot(iou_th, df_sum.loc[:, 'nr_FN'], '-o', label='False Negatives')

ax4 = ax3.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax4.set_ylabel('Counts FP', color=color)
ax4.plot(iou_th, df_sum.loc[:, 'nr_FP'], '-o', color=color, label='False Positives')
ax4.tick_params(axis='y', labelcolor=color)

ax3.legend(loc='upper left')
ax4.legend(loc='upper right')

ax3.set_title('Ensemble with SUM, IOU_th=0.1')

# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.3)
